# %% [markdown]
# <a href="https://colab.research.google.com/github/preyali/BD_assignments/blob/main/BDP_A1_TASK_B%26C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Preyali Dave**
# (202318028)

# %% [markdown]
# ##TASK B

# %% [markdown]
# DATASET FOR **SPOTIFY API**

# %%
import pandas as pd
import numpy as np

# %%
import requests

url = "https://spotify23.p.rapidapi.com/search/"

querystring = {"q":"<REQUIRED>","type":"multi","offset":"0","limit":"10","numberOfTopResults":"5"}

headers = {
	"X-RapidAPI-Key": "9ea08b2ebamsheb92e5225b24147p1cdf97jsned778d761f79",
	"X-RapidAPI-Host": "spotify23.p.rapidapi.com"
}

response = requests.get(url, headers=headers,params = querystring)

print(response.json())
# Out:
# {'albums': {'totalCount': 813, 'items': [{'data': {'uri': 'spotify:album:1rVhockt4RAiZFaK3M3zPB', 'name': 'No Jacket Required (2016 Remaster)', 'artists': {'items': [{'uri': 'spotify:artist:4lxfqrEsLX6N1N4OCSkILp', 'profile': {'name': 'Phil Collins'}}]}, 'coverArt': {'sources': [{'url': 'https://i.scdn.co/image/ab67616d00001e02441084621edb7c53ef303090', 'width': 300, 'height': 300}, {'url': 'https://i.scdn.co/image/ab67616d00004851441084621edb7c53ef303090', 'width': 64, 'height': 64}, {'url': 'https://i.scdn.co/image/ab67616d0000b273441084621edb7c53ef303090', 'width': 640, 'height': 640}]}, 'date': {'year': 1985}}}, {'data': {'uri': 'spotify:album:1f6C0igNf8jtwASukoTF6I', 'name': 'request', 'artists': {'items': [{'uri': 'spotify:artist:35jRIUtWCUITFLfjhYwkFx', 'profile': {'name': 'krage'}}]}, 'coverArt': {'sources': [{'url': 'https://i.scdn.co/image/ab67616d00001e02929e3211dc20f24a5867931c', 'width': 300, 'height': 300}, {'url': 'https://i.scdn.co/image/ab67616d00004851929e3211dc20f2
# ...

# %%
print(response.text)
# Out:
# {"albums":{"totalCount":813,"items":[{"data":{"uri":"spotify:album:1rVhockt4RAiZFaK3M3zPB","name":"No Jacket Required (2016 Remaster)","artists":{"items":[{"uri":"spotify:artist:4lxfqrEsLX6N1N4OCSkILp","profile":{"name":"Phil Collins"}}]},"coverArt":{"sources":[{"url":"https:\/\/i.scdn.co\/image\/ab67616d00001e02441084621edb7c53ef303090","width":300,"height":300},{"url":"https:\/\/i.scdn.co\/image\/ab67616d00004851441084621edb7c53ef303090","width":64,"height":64},{"url":"https:\/\/i.scdn.co\/image\/ab67616d0000b273441084621edb7c53ef303090","width":640,"height":640}]},"date":{"year":1985}}},{"data":{"uri":"spotify:album:1f6C0igNf8jtwASukoTF6I","name":"request","artists":{"items":[{"uri":"spotify:artist:35jRIUtWCUITFLfjhYwkFx","profile":{"name":"krage"}}]},"coverArt":{"sources":[{"url":"https:\/\/i.scdn.co\/image\/ab67616d00001e02929e3211dc20f24a5867931c","width":300,"height":300},{"url":"https:\/\/i.scdn.co\/image\/ab67616d00004851929e3211dc20f24a5867931c","width":64,"height":64},{"ur
# ...

# %%
type(response.json())
# Out:
# dict

# %%
import pandas as pd
from io import StringIO

df = pd.DataFrame.from_dict(response.json())
df
# Out:
#                                                        albums  \
# totalCount                                                813
# items       [{'data': {'uri': 'spotify:album:1rVhockt4RAiZ...
# featured                                                  NaN
#
#                                                       artists  \
# totalCount                                                 66
# items       [{'data': {'uri': 'spotify:artist:1g05P4Ua1FzC...
# featured                                                  NaN
#
#                                                      episodes genres  \
# totalCount                                               1000      0
# items       [{'data': {'uri': 'spotify:episode:6lgfrqAIUbD...     []
# featured                                                  NaN    NaN
#
#                                                     playlists  \
# totalCount                                                 54
# ...

# %%
ja = response.json()

# %%
for i, j in ja.items():
  print(i,j['items'])
# Out:
# albums [{'data': {'uri': 'spotify:album:1rVhockt4RAiZFaK3M3zPB', 'name': 'No Jacket Required (2016 Remaster)', 'artists': {'items': [{'uri': 'spotify:artist:4lxfqrEsLX6N1N4OCSkILp', 'profile': {'name': 'Phil Collins'}}]}, 'coverArt': {'sources': [{'url': 'https://i.scdn.co/image/ab67616d00001e02441084621edb7c53ef303090', 'width': 300, 'height': 300}, {'url': 'https://i.scdn.co/image/ab67616d00004851441084621edb7c53ef303090', 'width': 64, 'height': 64}, {'url': 'https://i.scdn.co/image/ab67616d0000b273441084621edb7c53ef303090', 'width': 640, 'height': 640}]}, 'date': {'year': 1985}}}, {'data': {'uri': 'spotify:album:1f6C0igNf8jtwASukoTF6I', 'name': 'request', 'artists': {'items': [{'uri': 'spotify:artist:35jRIUtWCUITFLfjhYwkFx', 'profile': {'name': 'krage'}}]}, 'coverArt': {'sources': [{'url': 'https://i.scdn.co/image/ab67616d00001e02929e3211dc20f24a5867931c', 'width': 300, 'height': 300}, {'url': 'https://i.scdn.co/image/ab67616d00004851929e3211dc20f24a5867931c', 'width': 64, 'height
# ...

# %%
for item in ja['albums']['items']:
    print(pd.DataFrame(item))
# Out:
#                                                        data
# artists   {'items': [{'uri': 'spotify:artist:4lxfqrEsLX6...
# coverArt  {'sources': [{'url': 'https://i.scdn.co/image/...
# date                                         {'year': 1985}
# name                     No Jacket Required (2016 Remaster)
# uri                    spotify:album:1rVhockt4RAiZFaK3M3zPB
#                                                        data
# artists   {'items': [{'uri': 'spotify:artist:35jRIUtWCUI...
# coverArt  {'sources': [{'url': 'https://i.scdn.co/image/...
# date                                         {'year': 2024}
# name                                                request
# uri                    spotify:album:1f6C0igNf8jtwASukoTF6I
#                                                        data
# artists   {'items': [{'uri': 'spotify:artist:4lxfqrEsLX6...
# coverArt  {'sources': [{'url': 'https://i.scdn.co/image/...
# date                                         {'year': 1985}
# ...

# %% [markdown]
# DATASET FOR **CHUCK NORRIS JOKES APLI**

# %%
import requests

url = "https://matchilling-chuck-norris-jokes-v1.p.rapidapi.com/jokes/random"

headers = {
	"accept": "application/json",
	"X-RapidAPI-Key": "9ea08b2ebamsheb92e5225b24147p1cdf97jsned778d761f79",
	"X-RapidAPI-Host": "matchilling-chuck-norris-jokes-v1.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'categories': [], 'created_at': '2020-01-05 13:42:20.841843', 'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png', 'id': 'Ihkv2SpVQrqnUfdB4nd3mQ', 'updated_at': '2020-01-05 13:42:20.841843', 'url': 'https://api.chucknorris.io/jokes/Ihkv2SpVQrqnUfdB4nd3mQ', 'value': 'Fred Long won the Oscar for Best Costume Design for Invasion USA, for providing Chuck Norris with tight jeans.'}

# %%
response.text
# Out:
# '{"categories":[],"created_at":"2020-01-05 13:42:20.841843","icon_url":"https://assets.chucknorris.host/img/avatar/chuck-norris.png","id":"Ihkv2SpVQrqnUfdB4nd3mQ","updated_at":"2020-01-05 13:42:20.841843","url":"https://api.chucknorris.io/jokes/Ihkv2SpVQrqnUfdB4nd3mQ","value":"Fred Long won the Oscar for Best Costume Design for Invasion USA, for providing Chuck Norris with tight jeans."}'

# %%
df = pd.DataFrame(response.json())
df
# Out:
# Empty DataFrame
# Columns: [categories, created_at, icon_url, id, updated_at, url, value]
# Index: []

# %% [markdown]
# DATASET FOR **BASEBALL API**

# %%
import requests

url = "https://baseball4.p.rapidapi.com/v1/mlb/schedule"

querystring = {"date":"2021-07-30"}

headers = {
	"X-RapidAPI-Key": "9ea08b2ebamsheb92e5225b24147p1cdf97jsned778d761f79",
	"X-RapidAPI-Host": "baseball4.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'meta': {'version': 'v1.0', 'status': 200, 'copywrite': 'https://devAPI.ai', 'date': '2021-07-30', 'totalEvents': 0, 'totalGames': 15, 'totalGamesInProgress': 0}, 'body': {'0': {'gamePk': 633094, 'gameGuid': 'cedf2489-1963-4910-b66a-ea0f2d0206d3', 'gameType': 'R', 'season': '2021', 'gameDate': '2021-07-30T23:05:00Z', 'officialDate': '2021-07-30', 'status': {'abstractGameState': 'Final', 'codedGameState': 'F', 'detailedState': 'Final', 'statusCode': 'F', 'startTimeTBD': False, 'abstractGameCode': 'F'}, 'teams': {'away': {'leagueRecord': {'wins': 50, 'losses': 55, 'pct': '.476'}, 'score': 3, 'team': {'id': 112, 'name': 'Chicago Cubs'}, 'isWinner': False, 'splitSquad': False, 'seriesNumber': 34}, 'home': {'leagueRecord': {'wins': 48, 'losses': 55, 'pct': '.466'}, 'score': 4, 'team': {'id': 120, 'name': 'Washington Nationals'}, 'isWinner': True, 'splitSquad': False, 'seriesNumber': 34}}, 'venue': {'id': 3309, 'name': 'Nationals Park'}, 'content': [], 'isTie': False, 'gameNumber': 1, 'pu
# ...

# %%
response.text
# Out:
# '{"meta":{"version":"v1.0","status":200,"copywrite":"https:\\/\\/devAPI.ai","date":"2021-07-30","totalEvents":0,"totalGames":15,"totalGamesInProgress":0},"body":{"0":{"gamePk":633094,"gameGuid":"cedf2489-1963-4910-b66a-ea0f2d0206d3","gameType":"R","season":"2021","gameDate":"2021-07-30T23:05:00Z","officialDate":"2021-07-30","status":{"abstractGameState":"Final","codedGameState":"F","detailedState":"Final","statusCode":"F","startTimeTBD":false,"abstractGameCode":"F"},"teams":{"away":{"leagueRecord":{"wins":50,"losses":55,"pct":".476"},"score":3,"team":{"id":112,"name":"Chicago Cubs"},"isWinner":false,"splitSquad":false,"seriesNumber":34},"home":{"leagueRecord":{"wins":48,"losses":55,"pct":".466"},"score":4,"team":{"id":120,"name":"Washington Nationals"},"isWinner":true,"splitSquad":false,"seriesNumber":34}},"venue":{"id":3309,"name":"Nationals Park"},"content":[],"isTie":false,"gameNumber":1,"publicFacing":true,"doubleHeader":"N","gamedayType":"P","tiebreaker":"N","calendarEventID":"1
# ...

# %%
df = pd.DataFrame(response.json())
df
# Out:
#                                    meta  \
# version                            v1.0
# status                              200
# copywrite             https://devAPI.ai
# date                         2021-07-30
# totalEvents                           0
# totalGames                           15
# totalGamesInProgress                  0
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# ...

# %% [markdown]
# ##TASK C

# %% [markdown]
# DATA SCARAPING FOR **CARPETS** ON AMAZON

# %%
import requests

url0 = "https://www.amazon.in/s?k=carpets&crid=24SSBUFFADRLK&sprefix=carp%2Caps%2C240&ref=nb_sb_noss_2"

headerstag =({'User Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36', "Accept-Language": "en-US,en;q=0.5","Accept-Encoding": "gzip, deflate, br"})

# %%
page = requests.get(url0,headers = headerstag)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://m.media-amazon.com" crossorigin>\n<link rel="preconnect" href="https://m.media-amazon.com" crossorigin>\n<link rel="dns-prefetch" href="https://completion.amazon.com" crossorigin>\n<link rel="preconnect" href="https://completion.amazon.com" crossorigin>\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n\n<!-- sp:end-feature:csm:head-open
# ...

# %%
from bs4 import BeautifulSoup as bs

# %%
html_data = bs(page.content, "html.parser")
html_data
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="preconnect"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# ...

# %%
links = html_data.find_all("a",attrs={'class':'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

# %%
links
# Out:
# [<a class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal" href="/Kashish-Rugs-Microfiber-Thickness-FEET-Grey/dp/B09FZ8BRKD" target="_blank"><span class="a-size-base-plus a-color-base a-text-normal">Carpet for Living Room Handmade Microfiber Cozy Super Soft &amp; Plush Fluffy Shaggy Rugs for Living Room and Bedroom 3 X 5 Feet Grey Yellow</span> </a>,
#  <a class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal" href="/Status-Printed-Vintage-Persian-Bedroom/dp/B07VD3XPGY" target="_blank"><span class="a-size-base-plus a-color-base a-text-normal">Status Contract 3 x 5 Feet Multi Printed Vintage Persian Carpet Rug Runner for Bedroom/Living Area/Home with Anti Slip Backing</span> </a>,
# ...

# %%
# Function to extract Product Title
def get_title(html_data):

    try:
        # Outer Tag Object
        title = html_data.find("span", attrs={"id":'productTitle'})

        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(_html_data):

    try:
        price = html_data.find("span", attrs={'class':'a-price aok-align-center'}).find('span',attrs ={'class':'a-offscreen'}).text

    except AttributeError:
      price = ""

        # try:
        #     # If there is some deal price
        #     price = html_data.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

        # except:
        #     price = ""

    return price

# Function to extract Product Rating
def get_rating(html_data):

    try:
        rating = html_data.find("i", attrs={'class':'a-icon a-icon-star a-star-5 cm-cr-review-stars-spacing-big'}).string.strip()

    except AttributeError:
        try:
            rating = html_data.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""

    return rating

# %%
# links = links[0].get('href')
links_list = []

for link in links:
  links_list.append(link.get('href'))

d = {"title":[], "price":[], "rating":[]}


for link in links_list:
  new_page = requests.get("https://www.amazon.in" + link, headers=headerstag)
  new_html = bs(new_page.content, "html.parser")
  d['title'].append(get_title(new_html))
  d['price'].append(get_price(new_html))
  d['rating'].append(get_rating(new_html))
        # d['reviews'].append(get_review_count(new_soup))
        # d['availability'].append(get_availability(new_soup))


  amazon_df = pd.DataFrame.from_dict(d)
  amazon_df['title'].replace('', np.nan, inplace=True)
  amazon_df = amazon_df.dropna(subset=['title'])
  amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                                 title price  \
# 0   Carpet for Living Room Handmade Microfiber Coz...
# 1   Status Contract 3 x 5 Feet Multi Printed Vinta...
# 2   ishro home 3 x 5 Feet 3D Jet Multi Printed 3D ...
# 3   BSB HOME Designer Superfine Chenille Carpet | ...
# 4   shetherug Home Decor Cotton Rug, Natural Fiber...
# 5   Welspun Wonder-Full Polyster Carpet, Machine W...
# 6   CHOUDHARY CARPET Home Decore - 5x7 Feet Persia...
# 7   SHARDHA Home Premium Carpets for Living Room/R...
# 8   JVK Heavy Fabric Velvet Touch Bedroom, Hall, L...
# 9   HOMA DORN Homadorn Handmade Sustainable Printe...
# 10  Status Contract 3 x 5 Feet Multi Printed Vinta...
# 11  ISEAU Soft Faux Fur Fluffy Area Rug, Luxury Fu...
# 12  Kuber Industries Superfine Velvet Carpet (Brow...
# 13  TONSYL 4x6 Bedroom Rug Washable Area Rugs for ...
# 14  Amazon Brand - Solimo 3D Printed Geometric Car...
# 15  Status Contract 3D Printed Vintage Persian Car...
# ...
